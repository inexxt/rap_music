# %% [markdown]
# ## 2.0 Intro
# Exploring and visualizing eloquency and strong language usage by rappers

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from pprint import pprint
import json
import os
from tqdm import tqdm
from collections import Counter
import numpy as np
import csv

# %% [markdown]
# Variables setting:

# %%
MAIN_PATH = "/home/jack/datasets/polish_rap/"
DICTIONARIES_PATH = "/home/jack/datasets/polish_dictionaries/"
DICTIONARY_NAME = "slownik_znormalizowany.json"

# %% [markdown]
# **VERSES_MAX** - only so many verses will be explored, to allow for comparision between more and less popular rappers

# %%
VERSES_MAX = 12000

# %%
RAPPERS_PATH = MAIN_PATH + "/stm_lyrics/"

# %% [markdown]
# ## 2.1 Strong language exploration
# We have a lemmatized version of strong language dictionary from the previous step, now we can check if rap music is really so full of strong language

# %%
def get_strong_words():
    with open(DICTIONARIES_PATH + "strong_language_lem.json", "r") as f:
        return json.load(f)

# %%
strongs = set(get_strong_words())

# %%
len(strongs)
# Out:
# 304

# %%
from random import shuffle

def get_all_strongs():
    rappers_strongs = {}
    strongs_count = Counter()
    rappers = os.listdir(RAPPERS_PATH)
    for rapper in rappers:
        songs = os.listdir(RAPPERS_PATH + rapper)
        shuffle(songs)
        num_songs = len(songs)
        num_strongs = 0
        for song in songs:
            with open(RAPPERS_PATH + rapper + "/" + song, "r") as f:
                song_text = json.load(f)
            song_words = song_text["lyrics"].split()
            strongs_in_song = list(filter(lambda x: x in strongs, song_words))
            num_strongs += len(strongs_in_song)
            strongs_count += Counter(strongs_in_song)
        rappers_strongs[rapper] = num_strongs/num_songs
    return rappers_strongs, strongs_count

# %%
all_rapers_strongs, strongs_count = get_all_strongs()

# %%
rappers_df = pd.DataFrame.from_dict(all_rapers_strongs, "index")
rappers_df.sort_values(by=0, inplace=True, ascending=False)

# %%
fig = plt.figure()
rappers_df[0].plot(kind="barh", figsize=(15, 40))
plt.axvline(x=float(rappers_df.median(0)), color="grey", linestyle="dashed")
plt.title("Strong language use by rapper - words/song")

# %% [markdown]
# Dashed line shows median

# %%
print("Median of curses per song is: " + str(rappers_df.median(0)[0]))
# Out:
# Median of curses per song is: 3.45186781609

# %% [markdown]
# ### Most popular curses

# %%
strongs_df = pd.Series(dict(strongs_count))
strongs_df[strongs_df > 100].sort_values().plot(kind="barh", figsize=(10,10))

# %% [markdown]
# ## 2.2 Eloquency exploration
# Now we can check which rappers are the most eloquent ones, measured by number of different words / all words they used.

# %%
def build_dict():
    with open(DICTIONARIES_PATH + DICTIONARY_NAME, "r") as f:
        return json.load(f)
slownik_pl_dict = build_dict()

# %%
def ok_word(word):
    return word in slownik_pl_dict

# %%
all_vocab = Counter()
rappers = os.listdir(RAPPERS_PATH)
for rapper in tqdm(rappers):
    songs = os.listdir(RAPPERS_PATH + rapper)
    for song in songs:
        with open(RAPPERS_PATH + rapper + "/" + song, "r") as f:
            song_text = json.load(f)
        song_words = song_text["lyrics"].split()
        all_vocab += Counter(song_words)
# Out:
# 100%|██████████| 82/82 [00:15<00:00,  3.52it/s]

# %%
# len(set(all_vocab))

# %%
all_ok_vocab = set(filter(ok_word, all_vocab))
len(all_ok_vocab)
# Out:
# 27590

# %%
from random import shuffle

def get_vocab():
    rappers_vocab = {}
    unique_words = {}
    rappers_len = {}
    rappers_nokwords = {}
    
    rappers = os.listdir(RAPPERS_PATH)
    
    for rapper in tqdm(rappers):
        rapper_vocab = Counter()
        rapper_nokwords = set()
        songs = os.listdir(RAPPERS_PATH + rapper)
        shuffle(songs)
        num_songs = len(songs)
        rapper_len = 0
        for song in songs:
            if rapper_len <= VERSES_MAX:
                with open(RAPPERS_PATH + rapper + "/" + song, "r") as f:
                    song_text = json.load(f)
                song_words = song_text["lyrics"].split()[:(VERSES_MAX - rapper_len)]
                #filter out every non-existent word
                song_words_ok = list(filter(ok_word, song_words))
                rapper_nokwords |= set(filter(lambda x: not ok_word(x), song_words))
                rapper_vocab += Counter(song_words_ok)
                rapper_len += len(song_words_ok) #maybe it would be better to include just song_words_ok
                other_words = set(all_vocab - rapper_vocab)
        unique_words[rapper] = set(rapper_vocab) - other_words
        rappers_vocab[rapper] = set(rapper_vocab)
        rappers_len[rapper] = rapper_len
        rappers_nokwords[rapper] = rapper_nokwords
#         print(rapper, " Unq:", len(unique_words[rapper]), "ALL", rapper_len, "Nok", 
#               len(rapper_nokwords), "Wds", len(rappers_vocab[rapper]))
    return rappers_vocab, unique_words, rappers_len, rappers_nokwords

# %%
rappers_vocab, unique_words, rappers_allwords, rappers_nokwords = get_vocab()
# Out:
# 100%|██████████| 82/82 [03:05<00:00,  2.13s/it]

# %%
vocab_df = pd.Series(rappers_vocab).to_frame("vocab")
unique_df = pd.Series(unique_words).to_frame("unique")
allwords_df = pd.Series(rappers_allwords).to_frame("allwords")
nokwords_df = pd.Series(rappers_nokwords).to_frame("nokwords")

frames = [vocab_df, unique_df, allwords_df, nokwords_df]
rap_df = pd.concat(frames, axis=1)

# %% [markdown]
# Number of processed verses per rapper

# %%
rappers_allwords
# Out:
# {'2sty': 12000,
#  'Abradab': 12000,
#  'Arach': 1617,
#  'Arow': 4568,
#  'Beteo': 6591,
#  'Bezczel': 12000,
#  'Biak': 2026,
#  'Blejk': 3461,
#  'Bonson': 12000,
#  'Borixon': 12000,
#  'Buka': 12000,
#  'Chevy': 1182,
#  'Czeski': 5027,
#  'Dejan': 7541,
#  'Deys': 12000,
#  'Diox': 11415,
#  'Diset': 11070,
#  'Eldo': 12000,
#  'Eripe': 12000,
#  'Fazi': 1448,
#  'Filipek': 12000,
#  'Flint': 12000,
#  'Flojd': 6792,
#  'Fokus': 12000,
#  'Gedz': 12000,
#  'Golin': 8119,
#  'Gonix': 2364,
#  'Gospel': 12000,
#  'Gres': 2979,
#  'Grubson': 12000,
#  'Guova': 3438,
#  'Hades': 8937,
#  'Hary': 8155,
#  'Igrekzet': 2192,
#  'Jimson': 10706,
#  'Jodsen': 7399,
#  'Joteste': 2476,
#  'Kajman': 12000,
#  'Kamel': 2647,
#  'Kartky': 12000,
#  'Kleszcz': 4272,
#  'Kobra': 11999,
#  'Koldi': 12000,
#  'Kotzi': 6860,
#  'Kubiszew': 8559,
#  'Laikike1': 12000,
#  'Lilu': 8006,
#  'Liroy': 11798,
#  'Mroku': 5147,
#  'Neile': 12000,
#  'Onar': 12000,
#  'Oxon': 12000,
#  'Paluch': 12000,
#  'Peja': 12000,
#  'Pelson': 11020,
#  'Penx': 12000,
#  'Proceente': 5682,
#  'Profeat': 1918,
#  'Prvski': 3823,
#  'Quebonafide': 12000,
#  'Rahim': 9029,
#  'Reno': 5963,
#  'Robak': 4498,
#  'Rover': 12000,
#  'Sarius': 12000,
#  'Shot': 3132,
#  'Sitek': 7980,
#  'Skorup': 7663,
#  'Sobota': 12000,
#  'Solar': 12000,
#  'Spinache': 4287,
#  'Stachursky': 574,
#  'Stasiak': 1834,
#  'Sztoss': 2927,
#  'Tede': 12000,
#  'Vixen': 12000,
#  'Warszawski': 4811,
#  'Wicher': 3171,
#  'Wini': 7101,
#  'Wuwunio': 3072,
#  'Zeus': 6785,
#  'Zkibwoy': 3597}

# %%
rap_df.head()
# Out:
#                                                      vocab  \
# 2sty     {dość, śmietnik, plątać, spotkać, przycisnąć, ...
# Abradab  {fantazja, dość, kapa, spotkać, małolata, lico...
# Arach    {trasa, ptak, opinia, biały, nadal, małolata, ...
# Arow     {dość, łapię, musiał, ciasny, obiad, wake, spo...
# Beteo    {dość, wyrwać, małolata, niszczyć, też, pogard...
#
#                                                     unique  allwords  \
# 2sty     {melasa, kalifat, gyros, niewierność, magellan...     12000
# Abradab  {ojcowski, kapa, cielesny, koklusz, scratchowa...     12000
# Arach    {fetować, wielorybi, zawrotny, nietolerancyjny...      1617
# Arow     {krwiodawstwo, nadzwyczaj, palcówka, karowy, o...      4568
# Beteo    {studencik, dwutygodniówka, aloes, palonka, up...      6591
#
#                                                   nokwords
# 2sty     {kingpiny, taksówą, j, sory, wirunek, niz, pen...
# Abradab  {spryciuch, tro, portos, j, męciu, phantomas, ...
# Arach    {bazuka, bushid, facebooka, panczach, play, ch...
# Arow     {veeegas, sativa, sory, pszem, laidback, flow,...
# Beteo    {x, iphone, trrtrr, kminisz, ławkiobcinammówię...

# %%
rap_df["vocab_size"] = rap_df["vocab"].map(len)
rap_df["unique_size"] = rap_df["unique"].map(len)
rap_df["nokwords_size"] = rap_df["nokwords"].map(len)
rap_df["eloquency"] = rap_df["vocab_size"] / rap_df["allwords"]

# %% [markdown]
# Comparision only makes sense if number of verses if >= **VERSES_MAX**/2, so there is no more than 2x difference between particular rappers

# %%
popular_rappers = rap_df[rap_df["allwords"] > VERSES_MAX/2]

# %%
len(popular_rappers)
# Out:
# 53

# %%
popular_rappers.sort_values(by="eloquency", ascending=False)
# Out:
#                                                          vocab  \
# Kotzi        {pastwa, spotkać, radomska, niszczyć, ciężko, ...
# Skorup       {dość, nieboskłon, śmietnik, wypieki, spotkać,...
# Golin        {fantazja, dość, wyrwać, spotkać, irak, syfili...
# Rahim        {fantazja, spotkać, nacierać, lico, uwieńczać,...
# Jodsen       {fantazja, dość, debiutant, tupolew, kometa, i...
# Jimson       {dość, spotkać, glut, małolata, bożek, sceneri...
# Hades        {dość, spotkać, małolata, wjebać, pokora, chwi...
# Dejan        {dość, wyrwać, spotkać, debiutant, małolata, d...
# Buka         {dość, wyrwać, spotkać, namiętnie, oh, wjebać,...
# Hary         {fantazja, dość, wyrwać, spotkać, małolata, oh...
# Peja         {fantazja, spotkać, małolata, oh, zwariowany, ...
# Flojd        {wyrwać, spotkać, małolata, wjebać, plask, pub...
# Deys         {przywiesić, dość, plątać, wyrwać, oh, wjebać,...
# Eldo         {dość, spotkać, oh, irak, przycisnąć, ślisko, ...
# Pelson       {wyrwać, spotkać, debiutant, kometa, publika, ...
# Paluch       {spotkać, małolata, wjebać, kometa, ulubieniec...
# Quebonafide  {fantazja, dość, krzyć, nacierać, oh, wjebać, ...
# Filipek      {dość, wyrwać, morgenstern, małolata, spotkać,...
# Eripe        {fantazja, dość, spotkać, małolata, drewniany,...
# Neile        {dość, plątać, wypieki, śmietnik, spotkać, zem...
# Wini         {dość, plątać, wyrwać, nieustanny, oh, wjebać,...
# Rover        {dość, śmietnik, wyrwać, spotkać, wjebać, kome...
# Kajman       {dość, nieboskłon, spotkać, pastwa, zemrzeć, z...
# Fokus        {nieboskłon, dość, wyrwać, spotkać, małolata, ...
# Zeus         {dość, wyrwać, spotkać, ukochać, niszczyć, też...
# Flint        {dość, wyrwać, spotkać, wjebać, mleko, publika...
# Gospel       {antybakteryjny, nieboskłon, tuczyć, dość, dis...
# Laikike1     {dość, śmietnik, wyrwać, spotkać, wjebać, efek...
# Oxon         {nieboskłon, dość, spotkać, małolata, uchroń, ...
# Beteo        {dość, wyrwać, małolata, niszczyć, też, pogard...
# Bezczel      {dość, śmietnik, wyrwać, spotkać, nieustanny, ...
# Abradab      {fantazja, dość, kapa, spotkać, małolata, lico...
# Kobra        {fantazja, dość, spotkać, małolata, oh, wjebać...
# Gedz         {fantazja, dość, śmietnik, wyrwać, spotkać, oh...
# Diox         {nieboskłon, dość, spotkać, publika, unosić, p...
# Solar        {dość, wyrwać, spotkać, małolata, irak, przyby...
# 2sty         {dość, śmietnik, plątać, spotkać, przycisnąć, ...
# Kubiszew     {spotkać, zwariowany, pokora, unosić, fraza, p...
# Sobota       {dość, spotkać, małolata, fraza, wytrzeźwieć, ...
# Diset        {dość, plątać, zwietrzały, wyrwać, spotkać, oh...
# Sarius       {dość, tuczyć, wyrwać, spotkać, małolata, oh, ...
# Grubson      {dość, wyrwać, spotkać, małolata, kometa, tupo...
# Penx         {dość, wyrwać, spotkać, oh, wjebać, kometa, śl...
# Sitek        {dość, spotkać, małolata, tupolew, potrzebnie,...
# Lilu         {plątać, spotkać, oh, mania, ukochać, też, dzi...
# Onar         {fantazja, śmietnik, wyrwać, przeraźliwie, spo...
# Kartky       {dość, spotkać, kometa, mania, publika, ukocha...
# Vixen        {fantazja, dość, wyrwać, spotkać, małolata, ko...
# Tede         {dość, spotkać, małolata, kwasy, tank, litość,...
# Borixon      {fantazja, dość, przywiesić, wyrwać, spotkać, ...
# Bonson       {dość, spotkać, dostały, unosić, rwać, wołać, ...
# Liroy        {fantazja, dość, spotkać, banalnie, wołać, też...
# Koldi        {wyrwać, spotkać, namiętnie, małolata, tupolew...
#
#                                                         unique  allwords  \
# Kotzi        {prymitywnie, skalniak, ufundować, wydmuchiwać...      6860
# Skorup       {podrzędny, dziuba, opiewać, odlotowy, ohio, g...      7663
# Golin        {dzwonnica, wynalazca, wymalować, arystokrata,...      8119
# Rahim        {nieostry, zaaferować, oczywistość, niziołek, ...      9029
# Jodsen       {farmakologia, kilowatogodzina, obopólny, pows...      7399
# Jimson       {kir, czadra, pośpieszny, przewodny, kandahar,...     10706
# Hades        {wok, przekształcić, podbudować, umożliwić, żw...      8937
# Dejan        {ekstradycja, ogier, michałek, zwiadowca, przy...      7541
# Buka         {chupa, upgrade, zdziwienie, rozsądność, zapro...     12000
# Hary         {sterylnie, zasyczeć, ciemnieć, ibuprofen, nie...      8155
# Peja         {przynależeć, szeląg, górska, neurotyczny, poł...     12000
# Flojd        {przebarwiać, college, sparcieć, flaki, wylicz...      6792
# Deys         {wichr, świetlicki, chamówa, przeistoczyć, łaj...     12000
# Eldo         {znój, szuch, wraży, odpór, globalnie, rozprys...     12000
# Pelson       {agrykola, szatnia, bezdroże, uproszczenie, ro...     11020
# Paluch       {potencja, remedium, szycha, zaprzyjaźnić, tle...     12000
# Quebonafide  {gołosłowność, żwirownia, dwudziestoczteroletn...     12000
# Filipek      {dezaktualizować, mirage, messa, legrand, arac...     12000
# Eripe        {doczołgać, heidegger, modelowy, wpełzać, wyża...     12000
# Neile        {diastema, porządkowy, upolitycznić, niedowidz...     12000
# Wini         {głodować, robaczywy, ułomność, nazmyślać, lem...      7101
# Rover        {wierzchołek, ratzinger, cudotwórczyni, wodoci...     12000
# Kajman       {przesył, kiwka, geremek, spona, geiger, odchy...     12000
# Fokus        {zatapialny, nieuk, pociec, radiowęzeł, znoić,...     12000
# Zeus         {komarów, otruwać, wypchnąć, żubrówka, wdzięki...      6785
# Flint        {parametr, tajniacki, pośpić, menadżerka, drop...     12000
# Gospel       {antybakteryjny, viktor, słonecznie, barć, dzy...     12000
# Laikike1     {utytłać, drakkar, chrzciny, linczować, musli,...     12000
# Oxon         {białawy, granatnik, egzystencjalny, witalność...     12000
# Beteo        {studencik, dwutygodniówka, aloes, palonka, up...      6591
# Bezczel      {walewska, zorać, obezwładniać, delfin, energe...     12000
# Abradab      {ojcowski, kapa, cielesny, koklusz, scratchowa...     12000
# Kobra        {jakubik, rockman, debra, singel, bug, blekaut...     11999
# Gedz         {minivan, ruleta, międzylądować, rozdwajać, ha...     12000
# Diox         {sekundowy, strząchać, stryków, bogota, clio, ...     11415
# Solar        {truchleć, teresiński, kuloodporny, koszykarz,...     12000
# 2sty         {melasa, kalifat, gyros, niewierność, magellan...     12000
# Kubiszew     {minusowy, spryciarz, wykrztusić, pb, obwołać,...      8559
# Sobota       {naskrobać, zulu, zdymać, jazzowy, poużywać, b...     12000
# Diset        {sekretarz, zakopiański, współzawodniczyć, dzi...     11070
# Sarius       {lewiatan, jednogłośnie, podwój, kontratak, dź...     12000
# Grubson      {jadźka, kaszuba, faszerować, aplikacja, obład...     12000
# Penx         {nielojalny, różańcowy, franko, oparcie, onkol...     12000
# Sitek        {wegetarianizm, luigi, lenno, stróżować, kompr...      7980
# Lilu         {mrzeć, sulej, ponadczasowość, potkać, zgryźć,...      8006
# Onar         {brzęk, sanatorium, parędziesiąt, przeraźliwie...     12000
# Kartky       {rumuński, kler, wariancja, nawałnica, legolan...     12000
# Vixen        {wajcha, wgryźć, półbóg, destylować, impulsywn...     12000
# Tede         {rabarbar, zmokły, spojler, kanabis, niejasny,...     12000
# Borixon      {corsa, rypać, pojemnościowy, powitanie, paniu...     12000
# Bonson       {czwartek, pomieszkać, ugadać, rozchwiać, prze...     12000
# Liroy        {alaski, poczerniały, bulka, zanieczyszczenie,...     11798
# Koldi        {ahonen, pourywać, podbitka, zaniżyć, tytoniow...     12000
#
#                                                       nokwords  vocab_size  \
# Kotzi        {policemanem, eurobusiness, czilaut, znajomych...        2353
# Skorup       {koluwa, fuck, you, rapgę, kista, siemano, pas...        2476
# Golin        {fokusa, heiligenstadzki, szczęsciem, amo, fuc...        2603
# Rahim        {umcy, fokusa, ajć, identico, spenia, j, mori,...        2790
# Jodsen       {beefy, spirit, j, kingsajz, echolokacyjnie, t...        2181
# Jimson       {bletki, cool, well, susupreme, brother, gomer...        2934
# Hades        {x, danceu, tach, fastfoodem, kupujsprzedaj, j...        2386
# Dejan        {flote, mori, hcę, kck, zajutrz, zystkim, łaku...        2012
# Buka         {upilem, hiper, blame, j, kolekturka, vida, ch...        3176
# Hary         {american, sasha, well, blue, sory, kfc, you, ...        2141
# Peja         {beefy, j, bronxie, undergrnadowy, dolargan, d...        3107
# Flojd        {x, flote, najki, steez, durex, thug, flojdem,...        1691
# Deys         {spree, spirit, deysa, cool, dore, bejb, warne...        2959
# Eldo         {dexter, x, eviva, antypersonalna, play, fifty...        2936
# Pelson       {himenen, blue, sory, j, nasem, rakaa, spike, ...        2688
# Paluch       {wuchtę, backstageu, egoizmuboli, vida, fuck, ...        2927
# Quebonafide  {beatelsów, tymek, huh, oneshota, weeman, hejt...        2875
# Filipek      {monica, well, eviva, backstageu, atencjamires...        2865
# Eripe        {beefy, sasha, j, sory, glebe, jebły, shemaleu...        2853
# Neile        {cake, blue, j, carne, łe, fuck, cadillaci, pr...        2852
# Wini         {eeeeesssaaaa, x, iphone, zagwostkę, prawilnyc...        1680
# Rover        {iphone, x, records, prapraprawdę, eurotrip, i...        2803
# Kajman       {cool, j, mori, cristiano, pizde, fuck, spóżni...        2795
# Fokus        {andżelina, nazwija, j, dile, tropez, udupom, ...        2790
# Zeus         {beefy, block, popierdoleniec, raider, gangste...        1577
# Flint        {bletki, beefy, beats, łódźjest, j, iałem, sco...        2776
# Gospel       {whiskacze, mappelle, j, pengiusz, south, kwas...        2776
# Laikike1     {beats, fraterom, sory, dawidgoliat, niz, vida...        2776
# Oxon         {wyjebanji, fuck, superduper, otrzebuję, nickl...        2737
# Beteo        {x, iphone, trrtrr, kminisz, ławkiobcinammówię...        1498
# Bezczel      {najarał, hnde, braggadacio, fairplay, fuck, v...        2721
# Abradab      {spryciuch, tro, portos, j, męciu, phantomas, ...        2712
# Kobra        {cool, enrique, j, psychopop, backstageu, tyy,...        2706
# Gedz         {beefy, vida, matters, hejterzy, bumblebee, si...        2704
# Diox         {square, cool, breakoutami, vitae, germont, so...        2562
# Solar        {tyrion, tutenhamon, j, fristajlem, dziwkoo, p...        2680
# 2sty         {kingpiny, taksówą, j, sory, wirunek, niz, pen...        2673
# Kubiszew     {x, dile, ziesz, tvkiem, game, vu, owu, lufecz...        1893
# Sobota       {vyjeban, cool, j, jetzt, nation, ihn, sing, m...        2629
# Diset        {square, naucze, advertising, him, tytex, etre...        2392
# Sarius       {bletki, sensej, fanpageach, braggadacio, bulw...        2580
# Grubson      {cool, stagowane, health, steva, handling, gdz...        2559
# Penx         {erwsze, moze, popatrze, well, daunom, skywalk...        2552
# Sitek        {heyah, x, bletki, clyde, flote, fuck, wudoe, ...        1678
# Lilu         {x, najki, przepitka, tupacu, backstageu, line...        1680
# Onar         {beefy, podpiździe, j, szieeea, lewaprawa, wyk...        2518
# Kartky       {mne, stark, bletki, well, fejkowe, niz, hopsi...        2466
# Vixen        {bletki, gatsby, zaaa, wkłądam, pomorzespróbuj...        2442
# Tede         {him, soute, j, vida, centertel, gębe, pasi, r...        2435
# Borixon      {żabson, mnnie, siódemą, wóde, onara, rrx, sie...        2406
# Bonson       {zechca, sory, znienawidza, spedaliła, liśmy, ...        2213
# Liroy        {cool, him, lifes, scooby, koooń, yeeah, zakre...        2163
# Koldi        {lambem, beefy, kachisukeonna, sięsiostro, dey...        2176
#
#              unique_size  nokwords_size  eloquency
# Kotzi                168            323   0.343003
# Skorup               113            207   0.323111
# Golin                176            237   0.320606
# Rahim                167            201   0.309004
# Jodsen                77            240   0.294770
# Jimson               128            325   0.274052
# Hades                 58            134   0.266980
# Dejan                 47            177   0.266808
# Buka                 121            444   0.264667
# Hary                  66            243   0.262538
# Peja                 120            290   0.258917
# Flojd                 19            151   0.248969
# Deys                 124            442   0.246583
# Eldo                  98            161   0.244667
# Pelson                62            195   0.243920
# Paluch                66            213   0.243917
# Quebonafide          114            563   0.239583
# Filipek              119            485   0.238750
# Eripe                 87            334   0.237750
# Neile                 85            281   0.237667
# Wini                  55            141   0.236586
# Rover                120            145   0.233583
# Kajman                80            285   0.232917
# Fokus                107            252   0.232500
# Zeus                  25             96   0.232424
# Flint                 65            282   0.231333
# Gospel               168            254   0.231333
# Laikike1             136            478   0.231333
# Oxon                  82            228   0.228083
# Beteo                 27            163   0.227280
# Bezczel               63            327   0.226750
# Abradab              148            177   0.226000
# Kobra                 64            498   0.225519
# Gedz                  75            385   0.225333
# Diox                  69            322   0.224442
# Solar                 98            345   0.223333
# 2sty                  72            349   0.222750
# Kubiszew              39            120   0.221171
# Sobota                69            401   0.219083
# Diset                 81            341   0.216079
# Sarius                68            288   0.215000
# Grubson               82            414   0.213250
# Penx                  55            309   0.212667
# Sitek                 25            134   0.210276
# Lilu                  49            150   0.209843
# Onar                  88            183   0.209833
# Kartky                59            277   0.205500
# Vixen                 56            211   0.203500
# Tede                  65            401   0.202917
# Borixon               54            228   0.200500
# Bonson                44            250   0.184417
# Liroy                 82            439   0.183336
# Koldi                 60            568   0.181333

# %%
popular_rappers.to_csv(MAIN_PATH + "popular_rappers.csv", sep="\t", encoding="utf-8")

# %%
if not os.path.exists(MAIN_PATH + "d2v_config/"):
    os.mkdir(MAIN_PATH + "d2v_config/")
popular_rappers.to_json("/home/jack/datasets/polish_rap/d2v_config/popular_rappers.json")

# %% [markdown]
# ### Examples ofno-ok words (words that haven't been found in the dictionary)

# %%
list(rap_df.ix["Peja"]["nokwords"])[:10]
# Out:
# ['beefy',
#  'j',
#  'bronxie',
#  'undergrnadowy',
#  'dolargan',
#  'decksa',
#  'kurestwo',
#  'blogo',
#  'headshot',
#  'biegusiem']
