# %% [markdown]
# ## 2.0 Intro
# Exploring and visualizing eloquency and strong language usage by rappers

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from pprint import pprint
import json
import os
from tqdm import tqdm
from collections import Counter
import numpy as np
import csv

# %% [markdown]
# Variables setting:

# %%
MAIN_PATH = "/home/jack/datasets/polish_rap/"
DICTIONARIES_PATH = "/home/jack/datasets/polish_dictionaries/"
DICTIONARY_NAME = "slownik_znormalizowany.json"

# %% [markdown]
# **VERSES_MAX** - only so many verses will be explored, to allow for comparision between more and less popular rappers

# %%
VERSES_MAX = 12000

# %%
RAPPERS_PATH = MAIN_PATH + "/stm_lyrics/"

# %% [markdown]
# ## 2.1 Strong language exploration
# We have a lemmatized version of strong language dictionary from the previous step, now we can check if rap music is really so full of strong language

# %%
def get_strong_words():
    with open(DICTIONARIES_PATH + "strong_language_lem.json", "r") as f:
        return json.load(f)

# %%
strongs = set(get_strong_words())

# %%
len(strongs)
# Out:
# 304

# %%
from random import shuffle

def get_all_strongs():
    rappers_strongs = {}
    strongs_count = Counter()
    rappers = os.listdir(RAPPERS_PATH)
    for rapper in rappers:
        songs = os.listdir(RAPPERS_PATH + rapper)
        shuffle(songs)
        num_songs = len(songs)
        num_strongs = 0
        for song in songs:
            with open(RAPPERS_PATH + rapper + "/" + song, "r") as f:
                song_text = json.load(f)
            song_words = song_text["lyrics"].split()
            strongs_in_song = list(filter(lambda x: x in strongs, song_words))
            num_strongs += len(strongs_in_song)
            strongs_count += Counter(strongs_in_song)
        rappers_strongs[rapper] = num_strongs/num_songs
    return rappers_strongs, strongs_count

# %%
all_rapers_strongs, strongs_count = get_all_strongs()

# %%
rappers_df = pd.DataFrame.from_dict(all_rapers_strongs, "index")
rappers_df.sort_values(by=0, inplace=True, ascending=False)

# %%
fig = plt.figure()
rappers_df[0].plot(kind="barh", figsize=(15, 40))
plt.axvline(x=float(rappers_df.median(0)), color="grey", linestyle="dashed")
plt.title("Strong language use by rapper - words/song")

# %% [markdown]
# Dashed line shows median

# %%
print("Median of curses per song is: " + str(rappers_df.median(0)[0]))
# Out:
# Median of curses per song is: 1.34615384615

# %% [markdown]
# ### Most popular curses

# %%
strongs_df = pd.Series(dict(strongs_count))
strongs_df[strongs_df > 100].sort_values().plot(kind="barh", figsize=(10,10))

# %% [markdown]
# ## 2.2 Eloquency exploration
# Now we can check which rappers are the most eloquent ones, measured by number of different words / all words they used.

# %%
def build_dict():
    with open(DICTIONARIES_PATH + DICTIONARY_NAME, "r") as f:
        return json.load(f)
slownik_pl_dict = build_dict()

# %%
def ok_word(word):
    return word in slownik_pl_dict

# %%
all_vocab = Counter()
rappers = os.listdir(RAPPERS_PATH)
for rapper in tqdm(rappers):
    songs = os.listdir(RAPPERS_PATH + rapper)
    for song in songs:
        with open(RAPPERS_PATH + rapper + "/" + song, "r") as f:
            song_text = json.load(f)
        song_words = song_text["lyrics"].split()
        all_vocab += Counter(song_words)
# Out:
# 100%|██████████| 82/82 [00:29<00:00,  1.73it/s]

# %%
# len(set(all_vocab))

# %%
all_ok_vocab = set(filter(ok_word, all_vocab))
# len(all_ok_vocab)

# %%
from random import shuffle

def get_vocab():
    rappers_vocab = {}
    unique_words = {}
    rappers_len = {}
    rappers_nokwords = {}
    
    rappers = os.listdir(RAPPERS_PATH)
    
    for rapper in tqdm(rappers):
        rapper_vocab = Counter()
        rapper_nokwords = set()
        songs = os.listdir(RAPPERS_PATH + rapper)
        shuffle(songs)
        num_songs = len(songs)
        rapper_len = 0
        for song in songs:
            if rapper_len <= VERSES_MAX:
                with open(RAPPERS_PATH + rapper + "/" + song, "r") as f:
                    song_text = json.load(f)
                song_words = song_text["lyrics"].split()[:(VERSES_MAX - rapper_len)]
                #filter out every non-existent word
                song_words_ok = list(filter(ok_word, song_words))
                rapper_nokwords |= set(filter(lambda x: not ok_word(x), song_words))
                rapper_vocab += Counter(song_words_ok)
                rapper_len += len(song_words_ok) #maybe it would be better to include just song_words_ok
                other_words = set(all_vocab - rapper_vocab)
        unique_words[rapper] = set(rapper_vocab) - other_words
        rappers_vocab[rapper] = set(rapper_vocab)
        rappers_len[rapper] = rapper_len
        rappers_nokwords[rapper] = rapper_nokwords
#         print(rapper, " Unq:", len(unique_words[rapper]), "ALL", rapper_len, "Nok", 
#               len(rapper_nokwords), "Wds", len(rappers_vocab[rapper]))
    return rappers_vocab, unique_words, rappers_len, rappers_nokwords

# %%
rappers_vocab, unique_words, rappers_allwords, rappers_nokwords = get_vocab()
# Out:
# 100%|██████████| 82/82 [06:20<00:00,  4.38s/it]

# %%
vocab_df = pd.Series(rappers_vocab).to_frame("vocab")
unique_df = pd.Series(unique_words).to_frame("unique")
allwords_df = pd.Series(rappers_allwords).to_frame("allwords")
nokwords_df = pd.Series(rappers_nokwords).to_frame("nokwords")

frames = [vocab_df, unique_df, allwords_df, nokwords_df]
rap_df = pd.concat(frames, axis=1)

# %% [markdown]
# Number of processed verses per rapper

# %%
rappers_allwords
# Out:
# {'2sty': 6970,
#  'Abradab': 12000,
#  'Arach': 1684,
#  'Arow': 4738,
#  'Beteo': 6280,
#  'Bezczel': 7572,
#  'Biak': 2116,
#  'Blejk': 3627,
#  'Bonson': 12000,
#  'Borixon': 12000,
#  'Buka': 12000,
#  'Chevy': 1257,
#  'Czeski': 5223,
#  'Dejan': 7848,
#  'Deys': 12000,
#  'Diox': 11819,
#  'Diset': 11425,
#  'Eldo': 12000,
#  'Eripe': 12000,
#  'Fazi': 1510,
#  'Filipek': 12000,
#  'Flint': 12000,
#  'Flojd': 7048,
#  'Fokus': 12000,
#  'Gedz': 12000,
#  'Golin': 8460,
#  'Gonix': 2462,
#  'Gospel': 12000,
#  'Gres': 3106,
#  'Grubson': 12000,
#  'Guova': 3578,
#  'Hades': 9367,
#  'Hary': 8501,
#  'Igrekzet': 2308,
#  'Jimson': 11096,
#  'Jodsen': 7354,
#  'Joteste': 2565,
#  'Kajman': 12000,
#  'Kamel': 2749,
#  'Kartky': 12000,
#  'Kleszcz': 4452,
#  'Kobra': 12000,
#  'Koldi': 12000,
#  'Kotzi': 7103,
#  'Kubiszew': 8936,
#  'Laikike1': 12000,
#  'Lilu': 8276,
#  'Liroy': 11992,
#  'Mroku': 5374,
#  'Neile': 12000,
#  'Onar': 12000,
#  'Oxon': 12000,
#  'Paluch': 12000,
#  'Peja': 12000,
#  'Pelson': 11541,
#  'Penx': 12000,
#  'Proceente': 5850,
#  'Profeat': 1983,
#  'Prvski': 4045,
#  'Quebonafide': 12000,
#  'Rahim': 9359,
#  'Reno': 6149,
#  'Robak': 4693,
#  'Rover': 12000,
#  'Sarius': 12000,
#  'Shot': 3223,
#  'Sitek': 8230,
#  'Skorup': 7963,
#  'Sobota': 12000,
#  'Solar': 12000,
#  'Spinache': 4469,
#  'Stachursky': 607,
#  'Stasiak': 1913,
#  'Sztoss': 3060,
#  'Tede': 12000,
#  'Vixen': 12000,
#  'Warszawski': 4980,
#  'Wicher': 3337,
#  'Wini': 7371,
#  'Wuwunio': 3187,
#  'Zeus': 6875,
#  'Zkibwoy': 3737}

# %%
rap_df.head()
# Out:
#                                                      vocab  \
# 2sty     {fortuny, łup, rymu, garażu, mecz, diablo, lep...
# Abradab  {zapalił, czegoś, rymu, przebiegły, chwila, lo...
# Arach    {przechodzi, prędzej, robiłem, tęczy, trampoli...
# Arow     {czegoś, chwila, zapewne, drugiego, przestanę,...
# Beteo    {odciążę, tato, bokiem, mecz, schodzi, celowy,...
#
#                                                     unique  allwords  \
# 2sty     {śledziu, izą, bałbyś, pleci, tuńczyka, zbiliś...      6970
# Abradab  {nieborak, jedynaczki, doszukując, niepospolit...     12000
# Arach    {przehula, przeją, trumnach, chłopem, trampoli...      1684
# Arow     {uzupełniać, ułóżmy, nieodebrane, majdańskiej,...      4738
# Beteo    {aloes, odciążę, oznakowane, styczniu, przepra...      6280
#
#                                                   nokwords
# 2sty     {gift, kielona, sory, free, taboolabelowarticl...
# Abradab  {timbuktu, faite, mettent, rrrrryszy, rozkmini...
# Arach    {facebooka, stylzwalniam, panczach, porn, zwro...
# Arow     {sory, żeś, taboolabelowarticlethumbnails, pez...
# Beteo    {beteo, nolifea, senk, byś, taboolabelowarticl...

# %%
rap_df["vocab_size"] = rap_df["vocab"].map(len)
rap_df["unique_size"] = rap_df["unique"].map(len)
rap_df["nokwords_size"] = rap_df["nokwords"].map(len)
rap_df["eloquency"] = rap_df["vocab_size"] / rap_df["allwords"]

# %% [markdown]
# Comparision only makes sense if number of verses if >= **VERSES_MAX**/2, so there is no more than 2x difference between particular rappers

# %%
popular_rappers = rap_df[rap_df["allwords"] > VERSES_MAX/2]

# %%
len(popular_rappers)
# Out:
# 54

# %%
popular_rappers.sort_values(by="eloquency", ascending=False)
# Out:
#                                                          vocab  \
# Kotzi        {wściekające, radzieckich, legendy, tato, chwi...
# Golin        {pogadałbym, koronę, pyłu, bronisz, toalecie, ...
# Skorup       {kupowaniu, czegoś, rymu, tato, przebiegły, na...
# Rahim        {kinem, psom, zapewne, szkód, ów, ameryki, szc...
# Jodsen       {czegoś, grubą, legendy, kompani, pyłu, pisząc...
# Bezczel      {anioły, upij, łup, skroń, ameryki, supeł, mog...
# Jimson       {fortuny, corolli, koronę, mono, hawaje, tato,...
# Hades        {dobiorą, grubą, czegoś, wydala, najwcześniej,...
# Peja         {podkreślam, śliskich, skroń, czegoś, legendy,...
# 2sty         {fortuny, łup, rymu, garażu, mecz, diablo, lep...
# Dejan        {kraczą, czegoś, wepchnięta, przetańczę, niedo...
# Hary         {dagny, chwila, podziemie, sznytach, kasie, ob...
# Eripe        {trzymał, koryta, zadaję, skroń, chwila, leszc...
# Buka         {zapalił, emerytura, sepleń, zespołem, nabyć, ...
# Paluch       {zniszczenie, bananowy, szmelc, skroń, oglądał...
# Flojd        {tato, bokiem, lokalu, basiu, zebrałem, ubrani...
# Rover        {kładł, fortuny, koryta, skroń, rozmywasz, cze...
# Pelson       {trzymał, fortuny, czegoś, hiob, bratu, legend...
# Eldo         {skroń, czegoś, kinem, grubą, chwila, schodzi,...
# Laikike1     {zapalił, legendy, czegoś, najebać, salowy, sz...
# Deys         {draska, mimika, questy, łup, terminy, czegoś,...
# Oxon         {mono, grubą, czegoś, rządki, spóźnianiu, chwi...
# Filipek      {mono, czegoś, ideałów, chwila, mecz, leszczy,...
# Reno         {czegoś, chwila, leszczy, jutro, gadki, playbo...
# Neile        {czegoś, rymu, aerobik, oglądała, legendy, dzi...
# Flint        {zadaję, czegoś, zabawić, pomagają, samosądu, ...
# Kobra        {trzymał, koryta, kraczą, psychiki, koronę, sk...
# Sarius       {stragan, sięgnął, pogadałbym, skroń, czegoś, ...
# Wini         {anioły, czegoś, pomagają, tato, zwierzęcej, p...
# Penx         {trzymał, koryta, zrównają, koronę, skroń, cze...
# Zeus         {czegoś, grubą, śpisz, bronisz, wyobrażać, pod...
# Kajman       {łup, mono, grubą, czegoś, zabawić, kaszlę, do...
# Diox         {trzymał, psychiki, koronę, swetry, czegoś, le...
# Beteo        {odciążę, tato, bokiem, mecz, schodzi, celowy,...
# Fokus        {kraczą, czegoś, gnaty, tato, bokiem, zapewne,...
# Abradab      {zapalił, czegoś, rymu, przebiegły, chwila, lo...
# Diset        {pokojowej, ortodoksem, czegoś, rzucania, wdzi...
# Gospel       {trzymał, łup, koronę, zadaję, kargul, chwila,...
# Solar        {mostach, psychiki, obciął, czegoś, rymu, naje...
# Vixen        {zależeć, anioły, koronę, czegoś, poukładany, ...
# Kartky       {zadaję, finezji, bratu, pomagają, dzielą, chw...
# Kubiszew     {czegoś, zespołem, rundzie, lokalu, opróżnione...
# Sobota       {uzewnętrzniam, upij, czegoś, zabawić, śpisz, ...
# Tede         {fortuny, psom, mecz, podziemie, korek, pozbąd...
# Onar         {załatwionych, suchym, pomagają, ideałów, śpis...
# Grubson      {fochów, bokiem, chwila, leszczy, wstań, przed...
# Borixon      {zadaję, czegoś, kaszlę, aerobik, najebać, nie...
# Quebonafide  {cell, hiob, tato, bokiem, zawdzięczasz, chwil...
# Sitek        {anioły, czegoś, hawaje, zszycia, tato, bokiem...
# Lilu         {mostach, poprawkę, czegoś, poratuje, chwila, ...
# Gedz         {trzymał, koryta, psychiki, igraliśmy, świętow...
# Bonson       {sięgnął, czegoś, kaszlę, przetańczę, bokiem, ...
# Koldi        {czegoś, najebać, zaoranym, śpisz, chwila, bed...
# Liroy        {transmisji, kangury, sięgnął, czegoś, zabawić...
#
#                                                         unique  allwords  \
# Kotzi        {wściekające, trzymaliśmy, radzieckich, zrywal...      7103
# Golin        {gobeliny, zapalisz, katedrą, papieski, szafra...      8460
# Skorup       {kupowaniu, wybrzydzać, piorunów, popędy, siwi...      7963
# Rahim        {pasożytne, matczynym, jebniętą, kropeczka, zb...      9359
# Jodsen       {oznaczył, abstynencję, obligacje, kobrę, zygm...      7354
# Bezczel      {kanibal, harda, namiętną, niewidzialne, psych...      7572
# Jimson       {klawiszy, potykając, szumy, kondomów, rozlałe...     11096
# Hades        {utknęli, tuńczyki, wiosennym, zaśnięcia, dobi...      9367
# Peja         {śliskich, teraźniejszy, narzeczonym, durną, u...     12000
# 2sty         {śledziu, izą, bałbyś, pleci, tuńczyka, zbiliś...      6970
# Dejan        {plamił, pudrów, jąkał, przyj, skleciłem, nied...      7848
# Hary         {celebrujesz, dagny, kowboja, ruszyłbyś, wyład...      8501
# Eripe        {pożywkę, odczyt, tajwański, pastwię, filantro...     12000
# Buka         {licealistach, emerytura, sepleń, smakosz, pop...     12000
# Paluch       {powtórzone, ogarniemy, paragrafem, obcymi, at...     12000
# Flojd        {pożyczała, szepczący, lenistwa, oznajm, wzglę...      7048
# Rover        {rozmywasz, tańczyłem, arteria, wykpił, schowa...     12000
# Pelson       {wypominają, uświadomiło, ubezpieczona, roleci...     11541
# Eldo         {wiertniczej, gwałtownie, zobowiązać, opętuję,...     12000
# Laikike1     {kosztowała, diwach, temperaturą, salowy, szla...     12000
# Deys         {draska, podbródkach, pogięte, przeglądy, ustr...     12000
# Oxon         {sikasz, zakukania, rządki, rykoszetem, spóźni...     12000
# Filipek      {wmówię, skokami, afrodyzjakiem, osman, napier...     12000
# Reno         {skumała, spędzimy, bankom, nadepnąć, nietęgie...      6149
# Neile        {plamkę, wyczerpany, tao, piołun, wysadzane, n...     12000
# Flint        {hangarach, samosądu, tranzystor, gimnazjalna,...     12000
# Kobra        {nasrana, piramidzie, popielniczki, przyniesie...     12000
# Sarius       {stragan, dobrotliwe, cierpiące, wyniosło, kwa...     12000
# Wini         {miałcy, narkotycznych, stopiły, ludziska, wyd...      7371
# Penx         {zrównają, pedicure, gombrowicza, wszczynał, r...     12000
# Zeus         {rozrastały, narożnikach, samookaleczeń, przeb...      6875
# Kajman       {dji, kapelmajster, dekalogiem, gwiazdorskich,...     12000
# Diox         {histeryczny, podziałami, rozpalisz, wieżowcem...     11819
# Beteo        {aloes, odciążę, oznakowane, styczniu, przepra...      6280
# Fokus        {włosie, angela, dynamity, studiami, ubłagana,...     12000
# Abradab      {nieborak, jedynaczki, doszukując, niepospolit...     12000
# Diset        {naśladuj, dewastuję, ahimsa, pokojowej, topor...     11425
# Gospel       {opętańca, uciekną, kargul, kastratowi, zmajst...     12000
# Solar        {obciął, liznęła, niezrozumieniem, zanieście, ...     12000
# Vixen        {walta, podkładać, bajpas, denaturatu, wyczerp...     12000
# Kartky       {plecakiem, dryfuję, otylia, wwierciłem, butel...     12000
# Kubiszew     {niezłamany, pokorni, ulegaj, lambert, ekstrem...      8936
# Sobota       {tyrając, wyobrażał, dedykować, uzewnętrzniam,...     12000
# Tede         {magazyny, iści, zasłonę, wymknął, zapieprzać,...     12000
# Onar         {odetchnijmy, miewają, jedzmy, załatwionych, s...     12000
# Grubson      {natur, odrabiałem, wywróciłem, porytych, kami...     12000
# Borixon      {gregory, przeholowałem, ścieli, kanciapę, jas...     12000
# Quebonafide  {cell, testerem, utył, rozbraja, migać, kaligr...     12000
# Sitek        {wstawałeś, lecieli, opanowana, osobom, rozpie...      8230
# Lilu         {ocuć, doskoczymy, przywitają, następcy, porat...      8276
# Gedz         {najmniejsze, twardowski, świętowitem, igraliś...     12000
# Bonson       {splotem, nadużywać, pytajcie, wyżył, węsząc, ...     12000
# Koldi        {procedury, obrączka, export, zaatakuję, triad...     12000
# Liroy        {transmisji, kangury, wstawiasz, stałby, pingp...     11992
#
#                                                       nokwords  vocab_size  \
# Kotzi        {bokoty, quake, hooray, taboolabelowarticlethu...        3125
# Golin        {nothing, our, type, byś, taboolabelowarticlet...        3610
# Skorup       {facebooka, byś, taboolabelowarticlethumbnails...        3346
# Rahim        {wodzirei, antyparchy, casa, perignon, byś, ta...        3705
# Jodsen       {byś, taboolabelowarticlethumbnails, ace, mode...        2892
# Bezczel      {jabadabadoo, moralniaka, beef, byś, taboolabe...        2893
# Jimson       {wyciągnełem, pijaru, byś, taboolabelowarticle...        4112
# Hades        {byś, taboolabelowarticlethumbnails, mode, cla...        3461
# Peja         {widowicho, beef, abercrombie, byś, taboolabel...        4429
# 2sty         {gift, kielona, sory, free, taboolabelowarticl...        2525
# Dejan        {liroya, bletką, rookiem, jaisu, byś, taboolab...        2842
# Hary         {fejmy, kfc, sory, byś, taboolabelowarticlethu...        3065
# Eripe        {six, beef, byś, taboolabelowarticlethumbnails...        4248
# Buka         {zaduka, rozkminiam, chłostki, byś, taboolabel...        4245
# Paluch       {give, fotę, beef, byś, taboolabelowarticlethu...        4210
# Flojd        {facebooka, odchłań, taboolabelowarticlethumbn...        2456
# Rover        {kpax, farci, byś, taboolabelowarticlethumbnai...        4140
# Pelson       {perignon, sory, byś, taboolabelowarticlethumb...        3980
# Eldo         {czystaw, bboy, oldschoolu, byś, taboolabelowa...        4096
# Laikike1     {steam, producentmc, six, beef, jogas, byś, ta...        4092
# Deys         {scoping, apriljoke, beef, taboolabelowarticle...        4088
# Oxon         {sky, halfman, byś, taboolabelowarticlethumbna...        4071
# Filipek      {rozkminisz, six, beef, hypemanach, free, tabo...        4042
# Reno         {bboy, taboolabelowarticlethumbnails, mode, ba...        2046
# Neile        {stevea, nothing, matatę, hakunę, byś, taboola...        3990
# Flint        {beef, demówy, byś, taboolabelowarticlethumbna...        3988
# Kobra        {policjajak, streeta, rozkminiam, luda, cypres...        3984
# Sarius       {guinessa, facebooka, rozkminiam, surwysyny, s...        3948
# Wini         {facebooka, byś, taboolabelowarticlethumbnails...        2371
# Penx         {rozkminisz, mafuria, rozkminiam, liu, sory, b...        3847
# Zeus         {uuu, evolution, byś, taboolabelowarticlethumb...        2203
# Kajman       {gift, fajbusiewicza, byś, taboolabelowarticle...        3844
# Diox         {wjezdzam, oszcercom, byś, taboolabelowarticle...        3784
# Beteo        {beteo, nolifea, senk, byś, taboolabelowarticl...        1997
# Fokus        {czk, taboolabelowarticlethumbnails, bambam, m...        3794
# Abradab      {timbuktu, faite, mettent, rrrrryszy, rozkmini...        3779
# Diset        {byś, taboolabelowarticlethumbnails, life, sma...        3594
# Gospel       {rozkminiam, zdejm, byś, taboolabelowarticleth...        3765
# Solar        {rozkminiam, beef, byś, taboolabelowarticlethu...        3749
# Vixen        {cedekach, cypress, byś, taboolabelowarticleth...        3720
# Kartky       {czil, wewenętrznej, byś, taboolabelowarticlet...        3715
# Kubiszew     {blokiulice, dżoja, noo, byś, taboolabelowarti...        2753
# Sobota       {rozkminiają, fiedzia, gamrot, taboolabelowart...        3693
# Tede         {uuuułłłiii, beef, byś, taboolabelowarticlethu...        3684
# Onar         {liroya, bouncey, beef, osw, byś, taboolabelow...        3596
# Grubson      {handling, microphone, ojojojojoj, byś, tabool...        3594
# Borixon      {wieżdżam, rozkminiają, byś, taboolabelowartic...        3573
# Quebonafide  {popping, hair, grantsa, caligae, free, tabool...        3538
# Sitek        {beef, byś, taboolabelowarticlethumbnails, lif...        2397
# Lilu         {feata, kielona, refrenx, custommade, byś, tab...        2373
# Gedz         {nothing, beef, porn, byś, taboolabelowarticle...        3377
# Bonson       {prosza, six, rozkminiam, beef, najków, sory, ...        3283
# Koldi        {teamkoldi, rozkminiam, beef, yardie, kamehame...        3228
# Liroy        {sciezka, liroyek, byś, taboolabelowarticlethu...        3090
#
#              unique_size  nokwords_size  eloquency
# Kotzi                536            340   0.439955
# Golin                529            248   0.426714
# Skorup               463            229   0.420193
# Rahim                578            217   0.395876
# Jodsen               287            255   0.393255
# Bezczel              217            271   0.382066
# Jimson               487            339   0.370584
# Hades                267            148   0.369489
# Peja                 524            400   0.369083
# 2sty                 189            247   0.362267
# Dejan                227            192   0.362130
# Hary                 277            261   0.360546
# Eripe                399            344   0.354000
# Buka                 535            435   0.353750
# Paluch               397            224   0.350833
# Flojd                136            168   0.348468
# Rover                446            152   0.345000
# Pelson               328            206   0.344857
# Eldo                 361            172   0.341333
# Laikike1             421            505   0.341000
# Deys                 502            417   0.340667
# Oxon                 373            247   0.339250
# Filipek              455            560   0.336833
# Reno                 127            180   0.332737
# Neile                383            273   0.332500
# Flint                386            299   0.332333
# Kobra                301            511   0.332000
# Sarius               355            260   0.329000
# Wini                 216            161   0.321666
# Penx                 229            297   0.320583
# Zeus                 157            119   0.320436
# Kajman               341            387   0.320333
# Diox                 319            339   0.320162
# Beteo                122            166   0.317994
# Fokus                431            240   0.316167
# Abradab              426            274   0.314917
# Diset                307            355   0.314573
# Gospel               551            267   0.313750
# Solar                350            342   0.312417
# Vixen                346            211   0.310000
# Kartky               271            279   0.309583
# Kubiszew             202            132   0.308080
# Sobota               326            210   0.307750
# Tede                 300            385   0.307000
# Onar                 252            168   0.299667
# Grubson              336            401   0.299500
# Borixon              309            250   0.297750
# Quebonafide          328            465   0.294833
# Sitek                169            152   0.291252
# Lilu                 198            166   0.286733
# Gedz                 248            319   0.281417
# Bonson               202            204   0.273583
# Koldi                260            544   0.269000
# Liroy                294            460   0.257672

# %%
popular_rappers.to_csv(MAIN_PATH + "popular_rappers.csv", sep="\t", encoding="utf-8")

# %%
if not os.path.exists(MAIN_PATH + "d2v_config/"):
    os.mkdir(MAIN_PATH + "d2v_config/")
popular_rappers.to_json("/home/jack/datasets/polish_rap/d2v_config/popular_rappers.json")

# %% [markdown]
# ### Examples ofno-ok words (words that haven't been found in the dictionary)

# %%
list(rap_df.ix["Peja"]["nokwords"])[:10]
# Out:
# ['widowicho',
#  'beef',
#  'abercrombie',
#  'byś',
#  'taboolabelowarticlethumbnails',
#  'peję',
#  'znow',
#  'twardziejto',
#  'rycha',
#  'made']
