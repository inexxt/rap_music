# %%
library(ggplot2)

df <- read.csv("/home/jack/datasets/polish_rap/rappers_coordinates.csv", sep=";")
options(repr.plot.width=8, repr.plot.height=6)


ggplot(data=df, aes(x, y, label=name)) +
    geom_point() + 
    geom_text(data = df, vjust=0)
# Out:
# plot without title
